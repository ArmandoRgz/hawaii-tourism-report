# %%
import pandas as pd

folder = "processed_frames"
filenames = ["hawaii-air_seats","hawaii-expenditure_patterns","hawaii-hotel_performance","hawaii-visitor_characteristics","hawaii-visitor_trends"]

air_seats = ["dim_as_market","dim_as_destination","fact_air_seats"]
expenditure_patterns = ["dim_ep_group","dim_ep_category","fact_expenditure"]
hotel_performance = ["dim_hp_category","fact_hotel"]
visitor_performance = ["dim_vc_group","fact_characteristics"]
visitor_trends = ["dim_vt_market","dim_vt_destination","fact_trends"]

# %%
first_schema = {}
second_schema = {}

for fname in filenames:
    path = f"{folder}/{fname}.csv"
    first_schema[fname] = pd.read_csv(path)
